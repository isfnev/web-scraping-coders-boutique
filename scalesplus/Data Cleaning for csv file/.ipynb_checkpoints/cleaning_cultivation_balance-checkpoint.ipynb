# %%
import pandas as pd

# %%
data = pd.read_csv('../csv_file/output_cultivation_scales.csv')

# %%
data.head()
# Out:
#                                                title  \
# 0  A&D Weighing Everest EK-600i Compact Balance, ...
# 1  OHAUS Adventurer AX4202N/E Precision Balance, ...
# 2  OHAUS Adventurer AX523N/E Precision Balance, 5...
# 3  OHAUS Adventurer AX8201N/E Precision Balance, ...
# 4  OHAUS PR522N/E Precision Balance, 520 g x 0.01...
#
#                                              image 1       msrp      price  \
# 0  https://cdn11.bigcommerce.com/s-errhy7umuu/ima...    $595.00    $425.72
# 1  https://cdn11.bigcommerce.com/s-errhy7umuu/ima...  $2,574.00  $2,187.90
# 2  https://cdn11.bigcommerce.com/s-errhy7umuu/ima...  $2,775.00  $2,358.75
# 3  https://cdn11.bigcommerce.com/s-errhy7umuu/ima...  $2,032.00  $1,727.20
# 4  https://cdn11.bigcommerce.com/s-errhy7umuu/ima...  $1,749.00  $1,486.65
#
#     saving    part #  calibration optional 1  \
# 0  $169.28   EK-600i                     NaN
# 1  $386.10  30122655                     NaN
# 2  $416.25  30100634                     NaN
# ...

# %%
data.describe()
# Out:
#        calibration optional 1  Specification Sensitivity Drift (ppm/°C)  \
# count                     0.0                                 24.000000
# mean                      NaN                                  3.354167
# std                       NaN                                  1.371124
# min                       NaN                                  1.500000
# 25%                       NaN                                  3.000000
# 50%                       NaN                                  3.000000
# 75%                       NaN                                  3.000000
# max                       NaN                                  9.000000
#
#        Specification Sensitivity Drift (ppm/C)  Specification Automatic Doors  \
# count                                      4.0                            0.0
# mean                                       3.0                            NaN
# std                                        0.0                            NaN
# ...

# %%
null_count = data.isnull().sum()
null_count
# Out:
# title                                                                 0
# image 1                                                               0
# msrp                                                                  0
# price                                                                 0
# saving                                                                0
#                                                                      ..
# Specification Sample Refresh Rate                                    43
# Specification Pan Dimensions                                         43
# Specification Overall Dimensions (W x D x H) with column vertical    44
# Specification Water and Dust-proof rating                            43
# Specification IP Rating                                              43
# Length: 139, dtype: int64
